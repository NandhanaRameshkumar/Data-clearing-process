# %% [markdown]
# <a href="https://colab.research.google.com/github/NandhanaRameshkumar/Data-clearing-process/blob/main/Data_clearing_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Employee ID': [1001, 1002, 1003, 1004, 1005],
    'Age': [25, 30, 28, 35, 22],
    'Salary': [50000, 70000, 65000, 80000, 45000],
    'Department': ['Marketing', 'Sales', 'Engineering', 'Management', 'IT']
}

# %%
df = pd.DataFrame(data)

# %%
duplicates = df.duplicated()
if duplicates.any():
    print("Duplicate rows found:")
    print(df[duplicates])

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['Salary'])
plt.xlabel('Employee Name')
plt.ylabel('Salary')
plt.title('Employee Salary Growth')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
print(df.to_string())
# Out:
#       Name  Employee ID  Age  Salary   Department
# 0    Alice         1001   25   50000    Marketing
# 1      Bob         1002   30   70000        Sales
# 2  Charlie         1003   28   65000  Engineering
# 3    David         1004   35   80000   Management
# 4      Eve         1005   22   45000           IT
